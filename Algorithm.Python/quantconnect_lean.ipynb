# %% [markdown]
# <a href="https://colab.research.google.com/github/ggraf159/FYP/blob/main/Algorithm.Python/quantconnect_lean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install QuantConnect Lean
from IPython.display import clear_output
# !pip install cython pandas jstyleson
clear_output(wait=True)
# !sudo apt install gnupg ca-certificates
clear_output(wait=True)
# !sudo apt-key adv --keyserver hkp://keyserver.ubuntu.com:80 --recv-keys 3FA7E0328081BFF6A14DA29AA6A19B38D3D831EF
clear_output(wait=True)
# !echo "deb https://download.mono-project.com/repo/ubuntu stable-bionic main" | sudo tee /etc/apt/sources.list.d/mono-official-stable.list
clear_output(wait=True)
# !sudo apt update
clear_output(wait=True)
# !sudo apt install -y mono-devel binutils mono-complete ca-certificates-mono mono-vbnc nuget referenceassemblies-pcl fsharp
clear_output(wait=True)
# !git clone https://github.com/QuantConnect/Lean.git tmp && mv tmp/* . && rm -rf tmp
clear_output(wait=True)
# !nuget restore QuantConnect.Lean.sln
# Out:
# =MSBuild auto-detection: using msbuild version '15.0' from '/usr/lib/mono/msbuild/15.0/bin'.
# Restoring packages for /content/DownloaderDataProvider/QuantConnect.DownloaderDataProvider.Launcher.csproj...
#   GET https://api.nuget.org/v3-flatcontainer/fasterflect/index.json
#   GET https://api.nuget.org/v3-flatcontainer/quantconnect.pythonnet/index.json
#   GET https://api.nuget.org/v3-flatcontainer/protobuf-net/index.json
#   GET https://api.nuget.org/v3-flatcontainer/dotnetzip/index.json
#   GET https://api.nuget.org/v3-flatcontainer/sharpziplib/index.json
#   GET https://api.nuget.org/v3-flatcontainer/mcmaster.extensions.commandlineutils/index.json
#   GET https://api.nuget.org/v3-flatcontainer/newtonsoft.json/index.json
#   GET https://api.nuget.org/v3-flatcontainer/restsharp/index.json
#   GET https://api.nuget.org/v3-flatcontainer/qlnet/index.json
#   GET https://api.nuget.org/v3-flatcontainer/nodatime/index.json
#   GET https://api.nuget.org/v3-flatcontainer/accord/index.json
#   GET https://api.nuget.org/v3-flatcontainer/accord.fuzzy/index.json
#   GET https://api.nuget.org/v3-flatcontainer/accord.machinelearning/index.json
#   GET https://api.nuget.org/v3-flatcontainer/accord.math/index.json
#   GET https://api.nuget.org/v3-flatcontainer/dynamicinterop/index.json
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.io.recyclablememorystream/index.json
#   GET https://api.nuget.org/v3-flatcontainer/accord.statistics/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.componentmodel.composition/index.json
#   GET https://api.nuget.org/v3-flatcontainer/csvhelper/index.json
#   GET https://api.nuget.org/v3-flatcontainer/mathnet.numerics/index.json
#   GET https://api.nuget.org/v3-flatcontainer/cloneextensions/index.json
#   OK https://api.nuget.org/v3-flatcontainer/protobuf-net/index.json 260ms
#   OK https://api.nuget.org/v3-flatcontainer/sharpziplib/index.json 258ms
#   OK https://api.nuget.org/v3-flatcontainer/restsharp/index.json 263ms
#   OK https://api.nuget.org/v3-flatcontainer/mcmaster.extensions.commandlineutils/index.json 270ms
#   OK https://api.nuget.org/v3-flatcontainer/newtonsoft.json/index.json 267ms
#   OK https://api.nuget.org/v3-flatcontainer/qlnet/index.json 267ms
#   GET https://api.nuget.org/v3-flatcontainer/qlnet/1.13.0/qlnet.1.13.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/protobuf-net/3.1.33/protobuf-net.3.1.33.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/sharpziplib/1.3.3/sharpziplib.1.3.3.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/dynamicinterop/index.json 277ms
#   OK https://api.nuget.org/v3-flatcontainer/accord.math/index.json 278ms
#   OK https://api.nuget.org/v3-flatcontainer/mathnet.numerics/index.json 259ms
#   GET https://api.nuget.org/v3-flatcontainer/restsharp/106.12.0/restsharp.106.12.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/dynamicinterop/0.9.1/dynamicinterop.0.9.1.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/accord.math/3.6.0/accord.math.3.6.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/protobuf-net/3.1.33/protobuf-net.3.1.33.nupkg 11ms
#   GET https://api.nuget.org/v3-flatcontainer/mcmaster.extensions.commandlineutils/2.6.0/mcmaster.extensions.commandlineutils.2.6.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/sharpziplib/1.3.3/sharpziplib.1.3.3.nupkg 9ms
#   GET https://api.nuget.org/v3-flatcontainer/newtonsoft.json/13.0.2/newtonsoft.json.13.0.2.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/qlnet/1.13.0/qlnet.1.13.0.nupkg 14ms
#   OK https://api.nuget.org/v3-flatcontainer/restsharp/106.12.0/restsharp.106.12.0.nupkg 9ms
#   OK https://api.nuget.org/v3-flatcontainer/dynamicinterop/0.9.1/dynamicinterop.0.9.1.nupkg 8ms
#   GET https://api.nuget.org/v3-flatcontainer/mathnet.numerics/5.0.0/mathnet.numerics.5.0.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/mcmaster.extensions.commandlineutils/2.6.0/mcmaster.extensions.commandlineutils.2.6.0.nupkg 8ms
#   OK https://api.nuget.org/v3-flatcontainer/accord.math/3.6.0/accord.math.3.6.0.nupkg 9ms
#   OK https://api.nuget.org/v3-flatcontainer/newtonsoft.json/13.0.2/newtonsoft.json.13.0.2.nupkg 11ms
#   OK https://api.nuget.org/v3-flatcontainer/mathnet.numerics/5.0.0/mathnet.numerics.5.0.0.nupkg 7ms
#   GET https://api.nuget.org/v3-flatcontainer/protobuf-net.core/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.componentmodel.annotations/index.json
#   OK https://api.nuget.org/v3-flatcontainer/fasterflect/index.json 837ms
#   GET https://api.nuget.org/v3-flatcontainer/fasterflect/3.0.0/fasterflect.3.0.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/fasterflect/3.0.0/fasterflect.3.0.0.nupkg 4ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.emit.ilgeneration/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.emit.lightweight/index.json
#   OK https://api.nuget.org/v3-flatcontainer/quantconnect.pythonnet/index.json 890ms
#   GET https://api.nuget.org/v3-flatcontainer/quantconnect.pythonnet/2.0.41/quantconnect.pythonnet.2.0.41.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/accord.statistics/index.json 858ms
#   OK https://api.nuget.org/v3-flatcontainer/dotnetzip/index.json 903ms
#   GET https://api.nuget.org/v3-flatcontainer/accord.statistics/3.6.0/accord.statistics.3.6.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/accord.fuzzy/index.json 889ms
#   OK https://api.nuget.org/v3-flatcontainer/accord/index.json 890ms
#   GET https://api.nuget.org/v3-flatcontainer/dotnetzip/1.16.0/dotnetzip.1.16.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/nodatime/index.json 895ms
#   OK https://api.nuget.org/v3-flatcontainer/csvhelper/index.json 864ms
#   OK https://api.nuget.org/v3-flatcontainer/system.componentmodel.annotations/index.json 235ms
#   GET https://api.nuget.org/v3-flatcontainer/accord.fuzzy/3.6.0/accord.fuzzy.3.6.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/accord/3.6.0/accord.3.6.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/nodatime/3.0.5/nodatime.3.0.5.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/accord.machinelearning/index.json 899ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.io.recyclablememorystream/index.json 889ms
#   OK https://api.nuget.org/v3-flatcontainer/accord.statistics/3.6.0/accord.statistics.3.6.0.nupkg 11ms
#   OK https://api.nuget.org/v3-flatcontainer/accord.fuzzy/3.6.0/accord.fuzzy.3.6.0.nupkg 9ms
#   OK https://api.nuget.org/v3-flatcontainer/dotnetzip/1.16.0/dotnetzip.1.16.0.nupkg 11ms
#   OK https://api.nuget.org/v3-flatcontainer/system.componentmodel.composition/index.json 881ms
#   OK https://api.nuget.org/v3-flatcontainer/nodatime/3.0.5/nodatime.3.0.5.nupkg 8ms
#   OK https://api.nuget.org/v3-flatcontainer/accord/3.6.0/accord.3.6.0.nupkg 10ms
#   OK https://api.nuget.org/v3-flatcontainer/cloneextensions/index.json 862ms
#   GET https://api.nuget.org/v3-flatcontainer/csvhelper/19.0.0/csvhelper.19.0.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/accord.machinelearning/3.6.0/accord.machinelearning.3.6.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.componentmodel.composition/6.0.0/system.componentmodel.composition.6.0.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/csvhelper/19.0.0/csvhelper.19.0.0.nupkg 6ms
#   GET https://api.nuget.org/v3-flatcontainer/system.componentmodel.annotations/4.7.0/system.componentmodel.annotations.4.7.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/cloneextensions/1.3.0/cloneextensions.1.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/accord.machinelearning/3.6.0/accord.machinelearning.3.6.0.nupkg 5ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.io.recyclablememorystream/2.3.2/microsoft.io.recyclablememorystream.2.3.2.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.componentmodel.composition/6.0.0/system.componentmodel.composition.6.0.0.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/cloneextensions/1.3.0/cloneextensions.1.3.0.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.io.recyclablememorystream/2.3.2/microsoft.io.recyclablememorystream.2.3.2.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/system.componentmodel.annotations/4.7.0/system.componentmodel.annotations.4.7.0.nupkg 11ms
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime.compilerservices.unsafe/index.json
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.emit.ilgeneration/index.json 214ms
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.emit.lightweight/index.json 213ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.emit.lightweight/4.7.0/system.reflection.emit.lightweight.4.7.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.emit.ilgeneration/4.7.0/system.reflection.emit.ilgeneration.4.7.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.emit.lightweight/4.7.0/system.reflection.emit.lightweight.4.7.0.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.emit.ilgeneration/4.7.0/system.reflection.emit.ilgeneration.4.7.0.nupkg 9ms
#   GET https://api.nuget.org/v3-flatcontainer/system.security.permissions/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.text.encoding.codepages/index.json
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.csharp/index.json
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime.compilerservices.unsafe/index.json 219ms
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime.compilerservices.unsafe/4.7.1/system.runtime.compilerservices.unsafe.4.7.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime.compilerservices.unsafe/4.7.1/system.runtime.compilerservices.unsafe.4.7.1.nupkg 2ms
#   OK https://api.nuget.org/v3-flatcontainer/system.security.permissions/index.json 212ms
#   GET https://api.nuget.org/v3-flatcontainer/system.security.permissions/4.7.0/system.security.permissions.4.7.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.text.encoding.codepages/index.json 216ms
#   GET https://api.nuget.org/v3-flatcontainer/system.text.encoding.codepages/4.7.1/system.text.encoding.codepages.4.7.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.security.permissions/4.7.0/system.security.permissions.4.7.0.nupkg 5ms
#   OK https://api.nuget.org/v3-flatcontainer/system.text.encoding.codepages/4.7.1/system.text.encoding.codepages.4.7.1.nupkg 6ms
#   GET https://api.nuget.org/v3-flatcontainer/system.security.accesscontrol/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.windows.extensions/index.json
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.csharp/index.json 235ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.csharp/4.5.0/microsoft.csharp.4.5.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.csharp/4.5.0/microsoft.csharp.4.5.0.nupkg 5ms
#   OK https://api.nuget.org/v3-flatcontainer/protobuf-net.core/index.json 850ms
#   GET https://api.nuget.org/v3-flatcontainer/protobuf-net.core/3.1.33/protobuf-net.core.3.1.33.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/protobuf-net.core/3.1.33/protobuf-net.core.3.1.33.nupkg 2ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/index.json
#   OK https://api.nuget.org/v3-flatcontainer/system.security.accesscontrol/index.json 213ms
#   GET https://api.nuget.org/v3-flatcontainer/system.security.accesscontrol/4.7.0/system.security.accesscontrol.4.7.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.windows.extensions/index.json 216ms
#   GET https://api.nuget.org/v3-flatcontainer/system.windows.extensions/4.7.0/system.windows.extensions.4.7.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.security.accesscontrol/4.7.0/system.security.accesscontrol.4.7.0.nupkg 6ms
#   OK https://api.nuget.org/v3-flatcontainer/system.windows.extensions/4.7.0/system.windows.extensions.4.7.0.nupkg 2ms
#   GET https://api.nuget.org/v3-flatcontainer/system.drawing.common/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.security.principal.windows/index.json
#   OK https://api.nuget.org/v3-flatcontainer/quantconnect.pythonnet/2.0.41/quantconnect.pythonnet.2.0.41.nupkg 831ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/index.json 208ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/3.1.1/microsoft.netcore.platforms.3.1.1.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/3.1.0/microsoft.netcore.platforms.3.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/3.1.1/microsoft.netcore.platforms.3.1.1.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/3.1.0/microsoft.netcore.platforms.3.1.0.nupkg 9ms
#   OK https://api.nuget.org/v3-flatcontainer/system.drawing.common/index.json 214ms
#   GET https://api.nuget.org/v3-flatcontainer/system.drawing.common/4.7.0/system.drawing.common.4.7.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.drawing.common/4.7.0/system.drawing.common.4.7.0.nupkg 3ms
#   OK https://api.nuget.org/v3-flatcontainer/system.security.principal.windows/index.json 212ms
#   GET https://api.nuget.org/v3-flatcontainer/system.security.principal.windows/4.7.0/system.security.principal.windows.4.7.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.security.principal.windows/4.7.0/system.security.principal.windows.4.7.0.nupkg 5ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.win32.systemevents/index.json
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.win32.systemevents/index.json 212ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.win32.systemevents/4.7.0/microsoft.win32.systemevents.4.7.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.win32.systemevents/4.7.0/microsoft.win32.systemevents.4.7.0.nupkg 3ms
# Installed Microsoft.NETCore.Platforms 3.1.1 from https://api.nuget.org/v3/index.json with content hash RmINcaqiEkawM9C8oxFMN/CZmn1fGKWVsosbSY/8ARUNdHqV47hqhPVbrG3qUqLaRQI5w4HuqFOqrbhoSWcH6w==.
# Installed Microsoft.NETCore.Platforms 3.1.0 from https://api.nuget.org/v3/index.json with content hash z7aeg8oHln2CuNulfhiLYxCVMPEwBl3rzicjvIX+4sUuCwvXw5oXQEtbiU2c0z4qYL5L3Kmx0mMA/+t/SbY67w==.
# Installed System.Windows.Extensions 4.7.0 from https://api.nuget.org/v3/index.json with content hash CeWTdRNfRaSh0pm2gDTJFwVaXfTq6Xwv/sA887iwPTneW7oMtMlpvDIO+U60+3GWTB7Aom6oQwv5VZVUhQRdPQ==.
# Installed Microsoft.Win32.SystemEvents 4.7.0 from https://api.nuget.org/v3/index.json with content hash mtVirZr++rq+XCDITMUdnETD59XoeMxSpLRIII7JRI6Yj0LEDiO1pPn0ktlnIj12Ix8bfvQqQDMMIF9wC98oCA==.
# Installed System.Security.AccessControl 4.7.0 from https://api.nuget.org/v3/index.json with content hash JECvTt5aFF3WT3gHpfofL2MNNP6v84sxtXxpqhLBCcDRzqsPBmHhQ6shv4DwwN2tRlzsUxtb3G9M3763rbXKDg==.
# Installed Microsoft.IO.RecyclableMemoryStream 2.3.2 from https://api.nuget.org/v3/index.json with content hash Oh1qXXFdJFcHozvb4H6XYLf2W0meZFuG0A+TfapFPj9z5fd4vxiARGEhAaLj/6XWQaMYIv4SH/9Q6H78Hw0E2Q==.
# Installed System.Security.Principal.Windows 4.7.0 from https://api.nuget.org/v3/index.json with content hash ojD0PX0XhneCsUbAZVKdb7h/70vyYMDYs85lwEI+LngEONe/17A0cFaRFqZU+sOEidcVswYWikYOQ9PPfjlbtQ==.
# Installed System.Drawing.Common 4.7.0 from https://api.nuget.org/v3/index.json with content hash v+XbyYHaZjDfn0ENmJEV1VYLgGgCTx1gnfOBcppowbpOAriglYgGCvFCPr2EEZyBvXlpxbEsTwkOlInl107ahA==.
# Installed NodaTime 3.0.5 from https://api.nuget.org/v3/index.json with content hash ctgx76GTZ3hcE0lV/XepXskkZ2m3F/XSftwb/a3vK+vSorbT3QhGgWp/ZNb13oyKQhBdFIPiISilvx49LQggtw==.
# Installed Microsoft.CSharp 4.5.0 from https://api.nuget.org/v3/index.json with content hash kaj6Wb4qoMuH3HySFJhxwQfe8R/sJsNJnANrvv8WdFPMoNbKY5htfNscv+LHCu5ipz+49m2e+WQXpLXr9XYemQ==.
# Installed DynamicInterop 0.9.1 from https://api.nuget.org/v3/index.json with content hash n21+Hd+tceX8lgaOosPV+Pne+YqnZUd5RLW3OhnsVxWRzYXiAIAKmKweHIePYeY+fmcn3N5tjkJyQUccFuL3bg==.
# Installed Accord.Fuzzy 3.6.0 from https://api.nuget.org/v3/index.json with content hash jQGcuUBReN7odJA4OTixVyVJujNW4w7VUZbEqWb9KZ7mYDJDdZUoE+FS1Kx89pIboFQQK7WFxGWSrKwE96g3vw==.
# Installed CloneExtensions 1.3.0 from https://api.nuget.org/v3/index.json with content hash 4YL85qfQuWplSQCIML3qAYb4dOHtujD2hCP0JVvai+jQGiM4HLZ8qFipoMwNOA8k16lTX/MaRVULb0kKAbfoOA==.
# Installed CsvHelper 19.0.0 from https://api.nuget.org/v3/index.json with content hash vUHF8wPOVvdtUQ4sXQI62jEIGcz5p7MG3Qf4Hazg+3EZQFh+UoTASEG0a1tsGmhNsHZ/Y+qRO+SgLMZO8jNcSg==.
# Installed fasterflect 3.0.0 from https://api.nuget.org/v3/index.json with content hash nXucxx84mYH+fS9U92a4Ak/MfWP0H204c8D2I64zsOQynnihhavO6HOCUcpp8HfKZMn3aNn01iv1bINnxH7Kow==.
# Installed RestSharp 106.12.0 from https://api.nuget.org/v3/index.json with content hash irOsQHe5nTJB0BKxGQnTX1dsgCPl5dLTxvL7gbl98JiFPiHMN4wpFyUG/66ZpaFCsIrPKh6XwozWXlwYe9JwYQ==.
# Installed QuantConnect.pythonnet 2.0.41 from https://api.nuget.org/v3/index.json with content hash LVErSqUN5Hrj1ivy8SX8JOHEhEnXKNhQIaaRW1tzVdZf9tAxbtGaYC5qNSWQT2RqV+MvAGNtQMMQF9Ulk9v8nQ==.
# Installed System.ComponentModel.Composition 6.0.0 from https://api.nuget.org/v3/index.json with content hash 60Qv+F7oxomOjJeTDA5Z4iCyFbQ0B/2Mi5HT+13pxxq0lVnu2ipbWMzFB+RWKr3wWKA8BSncXr9PH/fECwMX5Q==.
# Installed McMaster.Extensions.CommandLineUtils 2.6.0 from https://api.nuget.org/v3/index.json with content hash paiRzqvqdSFdcWVTXn6SzphajrpjFM5ERiGlgccL5J2lgHbty068D63Maqmj0VTG0G9ciP2m/NSIgGnNv8WOLw==.
# Installed System.Runtime.CompilerServices.Unsafe 4.7.1 from https://api.nuget.org/v3/index.json with content hash zOHkQmzPCn5zm/BH+cxC1XbUS3P4Yoi3xzW7eRgVpDR2tPGSzyMZ17Ig1iRkfJuY0nhxkQQde8pgePNiA7z7TQ==.
# Installed Accord 3.6.0 from https://api.nuget.org/v3/index.json with content hash xJyL8zhWcfb7eYp4EiXamEkUo3dAvAriOQTWTgulP31wH7BCZqp/rI62+mPn29xcCH8a0iCKRxjEh6p0NsIG1w==.
# Installed protobuf-net 3.1.33 from https://api.nuget.org/v3/index.json with content hash tv6wc8QvCjGOY/grQ/irxUWqRtHpVzOLY87+jvINxYOD5n0o4TX9RukJ/FRkVyMeQtLLhf/0okQFb4rQgoWt8A==.
# Installed System.Reflection.Emit.Lightweight 4.7.0 from https://api.nuget.org/v3/index.json with content hash a4OLB4IITxAXJeV74MDx49Oq2+PsF6Sml54XAFv+2RyWwtDBcabzoxiiJRhdhx+gaohLh4hEGCLQyBozXoQPqA==.
# Installed System.Security.Permissions 4.7.0 from https://api.nuget.org/v3/index.json with content hash dkOV6YYVBnYRa15/yv004eCGRBVADXw8qRbbNiCn/XpdJSUXkkUeIvdvFHkvnko4CdKMqG8yRHC4ox83LSlMsQ==.
# Installed System.Reflection.Emit.ILGeneration 4.7.0 from https://api.nuget.org/v3/index.json with content hash AucBYo3DSI0IDxdUjKksBcQJXPHyoPyrCXYURW1WDsLI4M65Ar/goSHjdnHOAY9MiYDNKqDlIgaYm+zL2hA1KA==.
# Installed System.ComponentModel.Annotations 4.7.0 from https://api.nuget.org/v3/index.json with content hash 0YFqjhp/mYkDGpU0Ye1GjE53HMp9UVfGN7seGpAMttAC0C40v5gw598jCgpbBLMmCo0E5YRLBv5Z2doypO49ZQ==.
# Installed SharpZipLib 1.3.3 from https://api.nuget.org/v3/index.json with content hash N8+hwhsKZm25tDJfWpBSW7EGhH/R7EMuiX+KJ4C4u+fCWVc1lJ5zg1u3S1RPPVYgTqhx/C3hxrqUpi6RwK5+Tg==.
# Installed Newtonsoft.Json 13.0.2 from https://api.nuget.org/v3/index.json with content hash R2pZ3B0UjeyHShm9vG+Tu0EBb2lC8b0dFzV9gVn50ofHXh9Smjk6kTn7A/FdAsC8B5cKib1OnGYOXxRBz5XQDg==.
# Installed protobuf-net.Core 3.1.33 from https://api.nuget.org/v3/index.json with content hash uq+KLED4Mwx1BnTE5TTtawQgaCRpajcbRKaYsEbY5biWWK1O5+rCBTd6+9EpK6CYxd2POUHkpwTslPs4SCoHOw==.
# Installed DotNetZip 1.16.0 from https://api.nuget.org/v3/index.json with content hash CS9sjjXF23FLIbwlLT5k/jXBYxVnLMn01lyAvN/hxFM+UDvSicjTPB9ZMA+Wp/QlvBPbD2pzkAXUp1O50gP/Lw==.
# Installed Accord.MachineLearning 3.6.0 from https://api.nuget.org/v3/index.json with content hash R9iqbkXy4vqXgbJtHV2eW79i7pi8HjZVyG+0WEbbHvNft/rkExN7/o6I53w0GlKQEUPVu12Gr1e6XLBEqw7rLw==.
# Installed System.Text.Encoding.CodePages 4.7.1 from https://api.nuget.org/v3/index.json with content hash i2fOvznVVgOOTLUz8FgSap/MsR98I4Iaoz99VXcOW/e7Y2OdY42zhYpBYpZyivk5alYY/UsOWAVswhtjxceodA==.
# Installed MathNet.Numerics 5.0.0 from https://api.nuget.org/v3/index.json with content hash pg1W2VwaEQMAiTpGK840hZgzavnqjlCMTVSbtVCXVyT+7AX4mc1o89SPv4TBlAjhgCOo9c1Y+jZ5m3ti2YgGgA==.
# Installed QLNet 1.13.0 from https://api.nuget.org/v3/index.json with content hash SX0SbUrnx7PErZlw8fUniM0nmAyy1dtYBnxH5peYXTuvGreUO2PFlgf1OMbnD781ZriYCiIHgGrWF3uyPxC55A==.
# Installed Accord.Statistics 3.6.0 from https://api.nuget.org/v3/index.json with content hash x5ZlX4bkC+OBPGG1cWt7lAWh5YeNadJ3vkfEgNv39EptsBr9Jj3ddRbfSce3oO5vQ6Q2RrtQyekNAL5d7pOkzA==.
# Installed Accord.Math 3.6.0 from https://api.nuget.org/v3/index.json with content hash mGhAp+ItUEFI/HUb8krKEwo2tB4SpVpTvZI5U9X+a5WKm8OSSW4Ern1fGq1jm6PXFbhFfhvLWC1WANc3fjrg0Q==.
# Generating MSBuild file /content/DownloaderDataProvider/obj/QuantConnect.DownloaderDataProvider.Launcher.csproj.nuget.g.props.
# Generating MSBuild file /content/DownloaderDataProvider/obj/QuantConnect.DownloaderDataProvider.Launcher.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/DownloaderDataProvider/obj/project.assets.json
# Restored /content/DownloaderDataProvider/QuantConnect.DownloaderDataProvider.Launcher.csproj (in 5.1 sec).
# Restoring packages for /content/Configuration/QuantConnect.Configuration.csproj...
# Generating MSBuild file /content/Configuration/obj/QuantConnect.Configuration.csproj.nuget.g.props.
# Generating MSBuild file /content/Configuration/obj/QuantConnect.Configuration.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Configuration/obj/project.assets.json
# Restored /content/Configuration/QuantConnect.Configuration.csproj (in 6 ms).
# Restoring packages for /content/Compression/QuantConnect.Compression.csproj...
# Generating MSBuild file /content/Compression/obj/QuantConnect.Compression.csproj.nuget.g.props.
# Generating MSBuild file /content/Compression/obj/QuantConnect.Compression.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Compression/obj/project.assets.json
# Restored /content/Compression/QuantConnect.Compression.csproj (in 5 ms).
# Restoring packages for /content/Common/QuantConnect.csproj...
# Generating MSBuild file /content/Common/obj/QuantConnect.csproj.nuget.g.props.
# Generating MSBuild file /content/Common/obj/QuantConnect.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Common/obj/project.assets.json
# Restored /content/Common/QuantConnect.csproj (in 17 ms).
# Restoring packages for /content/Brokerages/QuantConnect.Brokerages.csproj...
# Generating MSBuild file /content/Brokerages/obj/QuantConnect.Brokerages.csproj.nuget.g.props.
# Generating MSBuild file /content/Brokerages/obj/QuantConnect.Brokerages.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Brokerages/obj/project.assets.json
# Restored /content/Brokerages/QuantConnect.Brokerages.csproj (in 6 ms).
# Restoring packages for /content/Api/QuantConnect.Api.csproj...
# Generating MSBuild file /content/Api/obj/QuantConnect.Api.csproj.nuget.g.props.
# Generating MSBuild file /content/Api/obj/QuantConnect.Api.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Api/obj/project.assets.json
# Restored /content/Api/QuantConnect.Api.csproj (in 5 ms).
# Restoring packages for /content/AlgorithmFactory/QuantConnect.AlgorithmFactory.csproj...
# Generating MSBuild file /content/AlgorithmFactory/obj/QuantConnect.AlgorithmFactory.csproj.nuget.g.props.
# Generating MSBuild file /content/AlgorithmFactory/obj/QuantConnect.AlgorithmFactory.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/AlgorithmFactory/obj/project.assets.json
# Restored /content/AlgorithmFactory/QuantConnect.AlgorithmFactory.csproj (in 8 ms).
# Restoring packages for /content/Algorithm/QuantConnect.Algorithm.csproj...
# Generating MSBuild file /content/Algorithm/obj/QuantConnect.Algorithm.csproj.nuget.g.props.
# Generating MSBuild file /content/Algorithm/obj/QuantConnect.Algorithm.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Algorithm/obj/project.assets.json
# Restored /content/Algorithm/QuantConnect.Algorithm.csproj (in 6 ms).
# Restoring packages for /content/ToolBox/QuantConnect.ToolBox.csproj...
# Generating MSBuild file /content/ToolBox/obj/QuantConnect.ToolBox.csproj.nuget.g.props.
# Generating MSBuild file /content/ToolBox/obj/QuantConnect.ToolBox.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/ToolBox/obj/project.assets.json
# Restored /content/ToolBox/QuantConnect.ToolBox.csproj (in 7 ms).
# Restoring packages for /content/Tests/QuantConnect.Tests.csproj...
#   GET https://api.nuget.org/v3-flatcontainer/common.logging/index.json
#   GET https://api.nuget.org/v3-flatcontainer/common.logging.core/index.json
#   GET https://api.nuget.org/v3-flatcontainer/deedle/index.json
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.net.test.sdk/index.json
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.testplatform.objectmodel/index.json
#   GET https://api.nuget.org/v3-flatcontainer/moq/index.json
#   GET https://api.nuget.org/v3-flatcontainer/nunit/index.json
#   GET https://api.nuget.org/v3-flatcontainer/nunit3testadapter/index.json
#   GET https://api.nuget.org/v3-flatcontainer/netmq/index.json
#   GET https://api.nuget.org/v3-flatcontainer/plotly.net/index.json
#   GET https://api.nuget.org/v3-flatcontainer/plotly.net.csharp/index.json
#   GET https://api.nuget.org/v3-flatcontainer/plotly.net.interactive/index.json
#   OK https://api.nuget.org/v3-flatcontainer/common.logging.core/index.json 211ms
#   GET https://api.nuget.org/v3-flatcontainer/common.logging.core/3.4.1/common.logging.core.3.4.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/netmq/index.json 209ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.net.test.sdk/index.json 213ms
#   OK https://api.nuget.org/v3-flatcontainer/deedle/index.json 214ms
#   OK https://api.nuget.org/v3-flatcontainer/common.logging/index.json 216ms
#   OK https://api.nuget.org/v3-flatcontainer/moq/index.json 213ms
#   OK https://api.nuget.org/v3-flatcontainer/common.logging.core/3.4.1/common.logging.core.3.4.1.nupkg 3ms
#   GET https://api.nuget.org/v3-flatcontainer/netmq/4.0.1.6/netmq.4.0.1.6.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.net.test.sdk/16.9.4/microsoft.net.test.sdk.16.9.4.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.testplatform.objectmodel/index.json 214ms
#   OK https://api.nuget.org/v3-flatcontainer/plotly.net.csharp/index.json 211ms
#   GET https://api.nuget.org/v3-flatcontainer/moq/4.16.1/moq.4.16.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/nunit3testadapter/index.json 216ms
#   GET https://api.nuget.org/v3-flatcontainer/deedle/2.1.0/deedle.2.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/netmq/4.0.1.6/netmq.4.0.1.6.nupkg 5ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.net.test.sdk/16.9.4/microsoft.net.test.sdk.16.9.4.nupkg 4ms
#   OK https://api.nuget.org/v3-flatcontainer/moq/4.16.1/moq.4.16.1.nupkg 3ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.testplatform.objectmodel/16.9.4/microsoft.testplatform.objectmodel.16.9.4.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/common.logging/3.4.1/common.logging.3.4.1.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/plotly.net.csharp/0.13.0/plotly.net.csharp.0.13.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/nunit3testadapter/4.2.1/nunit3testadapter.4.2.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/deedle/2.1.0/deedle.2.1.0.nupkg 5ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.testplatform.objectmodel/16.9.4/microsoft.testplatform.objectmodel.16.9.4.nupkg 5ms
#   OK https://api.nuget.org/v3-flatcontainer/common.logging/3.4.1/common.logging.3.4.1.nupkg 6ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.testplatform.testhost/index.json
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.codecoverage/index.json
#   OK https://api.nuget.org/v3-flatcontainer/nunit3testadapter/4.2.1/nunit3testadapter.4.2.1.nupkg 6ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.csharp/4.0.1/microsoft.csharp.4.0.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.csharp/4.0.1/microsoft.csharp.4.0.1.nupkg 4ms
#   GET https://api.nuget.org/v3-flatcontainer/system.collections/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.diagnostics.debug/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.globalization/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.typeextensions/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime.extensions/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.threading/index.json
#   GET https://api.nuget.org/v3-flatcontainer/asyncio/index.json
#   GET https://api.nuget.org/v3-flatcontainer/nacl.net/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.dynamic.runtime/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.linq/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.linq.expressions/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.objectmodel/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.servicemodel.primitives/index.json
#   GET https://api.nuget.org/v3-flatcontainer/castle.core/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.valuetuple/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.threading.tasks.extensions/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.extensions/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.primitives/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.resources.resourcemanager/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime.interopservices/index.json
#   GET https://api.nuget.org/v3-flatcontainer/fsharp.core/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.metadata/index.json
#   GET https://api.nuget.org/v3-flatcontainer/nuget.frameworks/index.json
#   OK https://api.nuget.org/v3-flatcontainer/plotly.net.csharp/0.13.0/plotly.net.csharp.0.13.0.nupkg 213ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.testplatform.testhost/index.json 212ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.testplatform.testhost/16.9.4/microsoft.testplatform.testhost.16.9.4.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.testplatform.testhost/16.9.4/microsoft.testplatform.testhost.16.9.4.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.codecoverage/index.json 221ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.codecoverage/16.9.4/microsoft.codecoverage.16.9.4.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.codecoverage/16.9.4/microsoft.codecoverage.16.9.4.nupkg 5ms
#   OK https://api.nuget.org/v3-flatcontainer/system.collections/index.json 213ms
#   GET https://api.nuget.org/v3-flatcontainer/system.collections/4.0.11/system.collections.4.0.11.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.collections/4.0.11/system.collections.4.0.11.nupkg 9ms
#   OK https://api.nuget.org/v3-flatcontainer/system.diagnostics.debug/index.json 224ms
#   GET https://api.nuget.org/v3-flatcontainer/system.diagnostics.debug/4.0.11/system.diagnostics.debug.4.0.11.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.diagnostics.debug/4.0.11/system.diagnostics.debug.4.0.11.nupkg 4ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/1.0.1/microsoft.netcore.platforms.1.0.1.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.netcore.targets/index.json
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/1.0.1/microsoft.netcore.platforms.1.0.1.nupkg 3ms
#   OK https://api.nuget.org/v3-flatcontainer/system.globalization/index.json 258ms
#   GET https://api.nuget.org/v3-flatcontainer/system.globalization/4.0.11/system.globalization.4.0.11.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.typeextensions/index.json 214ms
#   OK https://api.nuget.org/v3-flatcontainer/system.threading/index.json 213ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.typeextensions/4.1.0/system.reflection.typeextensions.4.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime.extensions/index.json 215ms
#   GET https://api.nuget.org/v3-flatcontainer/system.threading/4.0.11/system.threading.4.0.11.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.globalization/4.0.11/system.globalization.4.0.11.nupkg 6ms
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime.extensions/4.1.0/system.runtime.extensions.4.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/nacl.net/index.json 209ms
#   GET https://api.nuget.org/v3-flatcontainer/nacl.net/0.1.13/nacl.net.0.1.13.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.threading/4.0.11/system.threading.4.0.11.nupkg 11ms
#   OK https://api.nuget.org/v3-flatcontainer/system.dynamic.runtime/index.json 218ms
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime.extensions/4.1.0/system.runtime.extensions.4.1.0.nupkg 12ms
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.typeextensions/4.1.0/system.reflection.typeextensions.4.1.0.nupkg 15ms
#   GET https://api.nuget.org/v3-flatcontainer/system.dynamic.runtime/4.0.11/system.dynamic.runtime.4.0.11.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/nacl.net/0.1.13/nacl.net.0.1.13.nupkg 16ms
#   OK https://api.nuget.org/v3-flatcontainer/system.objectmodel/index.json 212ms
#   OK https://api.nuget.org/v3-flatcontainer/system.linq/index.json 216ms
#   OK https://api.nuget.org/v3-flatcontainer/system.linq.expressions/index.json 216ms
#   OK https://api.nuget.org/v3-flatcontainer/system.servicemodel.primitives/index.json 211ms
#   OK https://api.nuget.org/v3-flatcontainer/system.dynamic.runtime/4.0.11/system.dynamic.runtime.4.0.11.nupkg 5ms
#   GET https://api.nuget.org/v3-flatcontainer/system.objectmodel/4.0.12/system.objectmodel.4.0.12.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.linq/4.1.0/system.linq.4.1.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.servicemodel.primitives/4.4.0/system.servicemodel.primitives.4.4.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.linq/4.1.0/system.linq.4.1.0.nupkg 4ms
#   GET https://api.nuget.org/v3-flatcontainer/system.linq.expressions/4.1.0/system.linq.expressions.4.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.objectmodel/4.0.12/system.objectmodel.4.0.12.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/system.linq.expressions/4.1.0/system.linq.expressions.4.1.0.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/system.servicemodel.primitives/4.4.0/system.servicemodel.primitives.4.4.0.nupkg 20ms
#   OK https://api.nuget.org/v3-flatcontainer/castle.core/index.json 262ms
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.primitives/index.json 233ms
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime/index.json 230ms
#   OK https://api.nuget.org/v3-flatcontainer/system.valuetuple/index.json 265ms
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime/4.1.0/system.runtime.4.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime.interopservices/index.json 231ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.primitives/4.0.1/system.reflection.primitives.4.0.1.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/castle.core/4.4.0/castle.core.4.4.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.threading.tasks.extensions/index.json 269ms
#   GET https://api.nuget.org/v3-flatcontainer/system.valuetuple/4.5.0/system.valuetuple.4.5.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime.interopservices/4.1.0/system.runtime.interopservices.4.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.resources.resourcemanager/index.json 244ms
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime/4.1.0/system.runtime.4.1.0.nupkg 9ms
#   GET https://api.nuget.org/v3-flatcontainer/system.threading.tasks.extensions/4.5.4/system.threading.tasks.extensions.4.5.4.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.primitives/4.0.1/system.reflection.primitives.4.0.1.nupkg 11ms
#   OK https://api.nuget.org/v3-flatcontainer/system.valuetuple/4.5.0/system.valuetuple.4.5.0.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime.interopservices/4.1.0/system.runtime.interopservices.4.1.0.nupkg 8ms
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.extensions/index.json 255ms
#   OK https://api.nuget.org/v3-flatcontainer/castle.core/4.4.0/castle.core.4.4.0.nupkg 9ms
#   GET https://api.nuget.org/v3-flatcontainer/system.resources.resourcemanager/4.0.1/system.resources.resourcemanager.4.0.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/fsharp.core/index.json 229ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.extensions/4.0.1/system.reflection.extensions.4.0.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection/index.json 304ms
#   OK https://api.nuget.org/v3-flatcontainer/system.threading.tasks.extensions/4.5.4/system.threading.tasks.extensions.4.5.4.nupkg 23ms
#   OK https://api.nuget.org/v3-flatcontainer/nuget.frameworks/index.json 225ms
#   OK https://api.nuget.org/v3-flatcontainer/system.resources.resourcemanager/4.0.1/system.resources.resourcemanager.4.0.1.nupkg 8ms
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.extensions/4.0.1/system.reflection.extensions.4.0.1.nupkg 5ms
#   GET https://api.nuget.org/v3-flatcontainer/fsharp.core/4.5.2/fsharp.core.4.5.2.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.private.servicemodel/index.json
#   GET https://api.nuget.org/v3-flatcontainer/nuget.frameworks/5.0.0/nuget.frameworks.5.0.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection/4.1.0/system.reflection.4.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection/4.1.0/system.reflection.4.1.0.nupkg 8ms
#   OK https://api.nuget.org/v3-flatcontainer/fsharp.core/4.5.2/fsharp.core.4.5.2.nupkg 19ms
#   OK https://api.nuget.org/v3-flatcontainer/nuget.frameworks/5.0.0/nuget.frameworks.5.0.0.nupkg 55ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.netcore.targets/index.json 247ms
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.netcore.targets/1.0.1/microsoft.netcore.targets.1.0.1.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.threading.tasks/index.json
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.netcore.targets/1.0.1/microsoft.netcore.targets.1.0.1.nupkg 17ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.emit/index.json
#   OK https://api.nuget.org/v3-flatcontainer/nunit/index.json 828ms
#   OK https://api.nuget.org/v3-flatcontainer/plotly.net/index.json 832ms
#   OK https://api.nuget.org/v3-flatcontainer/plotly.net.interactive/index.json 835ms
#   GET https://api.nuget.org/v3-flatcontainer/nunit/3.13.3/nunit.3.13.3.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/plotly.net.interactive/5.0.0/plotly.net.interactive.5.0.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/plotly.net/5.1.0/plotly.net.5.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/nunit/3.13.3/nunit.3.13.3.nupkg 8ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.emit.ilgeneration/4.0.1/system.reflection.emit.ilgeneration.4.0.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.emit.ilgeneration/4.0.1/system.reflection.emit.ilgeneration.4.0.1.nupkg 10ms
#   GET https://api.nuget.org/v3-flatcontainer/system.io/index.json
#   GET https://api.nuget.org/v3-flatcontainer/netstandard.library/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.collections.specialized/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.componentmodel/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.componentmodel.typeconverter/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.diagnostics.tracesource/index.json
#   GET https://api.nuget.org/v3-flatcontainer/system.dynamic.runtime/4.3.0/system.dynamic.runtime.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection/4.3.0/system.reflection.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.dynamic.runtime/4.3.0/system.dynamic.runtime.4.3.0.nupkg 9ms
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection/4.3.0/system.reflection.4.3.0.nupkg 15ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.typeextensions/4.3.0/system.reflection.typeextensions.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.threading.tasks/index.json 257ms
#   GET https://api.nuget.org/v3-flatcontainer/system.threading.tasks/4.0.11/system.threading.tasks.4.0.11.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.typeextensions/4.3.0/system.reflection.typeextensions.4.3.0.nupkg 8ms
#   OK https://api.nuget.org/v3-flatcontainer/system.threading.tasks/4.0.11/system.threading.tasks.4.0.11.nupkg 7ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.emit.lightweight/4.0.1/system.reflection.emit.lightweight.4.0.1.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.xml.xmldocument/index.json
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.emit.lightweight/4.0.1/system.reflection.emit.lightweight.4.0.1.nupkg 8ms
#   GET https://api.nuget.org/v3-flatcontainer/system.collections/4.3.0/system.collections.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.diagnostics.debug/4.3.0/system.diagnostics.debug.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.collections/4.3.0/system.collections.4.3.0.nupkg 12ms
#   OK https://api.nuget.org/v3-flatcontainer/plotly.net.interactive/5.0.0/plotly.net.interactive.5.0.0.nupkg 219ms
#   OK https://api.nuget.org/v3-flatcontainer/plotly.net/5.1.0/plotly.net.5.1.0.nupkg 217ms
#   OK https://api.nuget.org/v3-flatcontainer/system.diagnostics.debug/4.3.0/system.diagnostics.debug.4.3.0.nupkg 13ms
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime/4.3.0/system.runtime.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime/4.3.0/system.runtime.4.3.0.nupkg 5ms
#   GET https://api.nuget.org/v3-flatcontainer/system.linq/4.3.0/system.linq.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.io/index.json 217ms
#   GET https://api.nuget.org/v3-flatcontainer/system.io/4.1.0/system.io.4.1.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.linq.expressions/4.3.0/system.linq.expressions.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.objectmodel/4.3.0/system.objectmodel.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/1.1.0/microsoft.netcore.platforms.1.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.linq.expressions/4.3.0/system.linq.expressions.4.3.0.nupkg 4ms
#   OK https://api.nuget.org/v3-flatcontainer/system.linq/4.3.0/system.linq.4.3.0.nupkg 9ms
#   OK https://api.nuget.org/v3-flatcontainer/system.io/4.1.0/system.io.4.1.0.nupkg 9ms
#   OK https://api.nuget.org/v3-flatcontainer/system.objectmodel/4.3.0/system.objectmodel.4.3.0.nupkg 5ms
#   GET https://api.nuget.org/v3-flatcontainer/fsharp.core/8.0.300/fsharp.core.8.0.300.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.dotnet.interactive/index.json
#   OK https://api.nuget.org/v3-flatcontainer/asyncio/index.json 847ms
#   GET https://api.nuget.org/v3-flatcontainer/asyncio/0.1.69/asyncio.0.1.69.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.netcore.targets/1.1.0/microsoft.netcore.targets.1.1.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/asyncio/0.1.69/asyncio.0.1.69.nupkg 9ms
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.netcore.targets/1.1.0/microsoft.netcore.targets.1.1.0.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/netstandard.library/index.json 211ms
#   OK https://api.nuget.org/v3-flatcontainer/system.collections.specialized/index.json 214ms
#   GET https://api.nuget.org/v3-flatcontainer/system.io/4.3.0/system.io.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.primitives/4.3.0/system.reflection.primitives.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.componentmodel.typeconverter/index.json 216ms
#   OK https://api.nuget.org/v3-flatcontainer/system.componentmodel/index.json 217ms
#   GET https://api.nuget.org/v3-flatcontainer/netstandard.library/1.6.1/netstandard.library.1.6.1.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/netstandard.library/2.0.0/netstandard.library.2.0.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/microsoft.dotnet.interactive.formatting/index.json
#   OK https://api.nuget.org/v3-flatcontainer/microsoft.netcore.platforms/1.1.0/microsoft.netcore.platforms.1.1.0.nupkg 67ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.emit.ilgeneration/4.3.0/system.reflection.emit.ilgeneration.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.resources.resourcemanager/4.3.0/system.resources.resourcemanager.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.runtime.extensions/4.3.0/system.runtime.extensions.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.emit.ilgeneration/4.3.0/system.reflection.emit.ilgeneration.4.3.0.nupkg 3ms
#   OK https://api.nuget.org/v3-flatcontainer/system.resources.resourcemanager/4.3.0/system.resources.resourcemanager.4.3.0.nupkg 15ms
#   OK https://api.nuget.org/v3-flatcontainer/netstandard.library/2.0.0/netstandard.library.2.0.0.nupkg 39ms
#   GET https://api.nuget.org/v3-flatcontainer/system.componentmodel.typeconverter/4.3.0/system.componentmodel.typeconverter.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.componentmodel/4.3.0/system.componentmodel.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.collections.specialized/4.3.0/system.collections.specialized.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.runtime.extensions/4.3.0/system.runtime.extensions.4.3.0.nupkg 8ms
#   OK https://api.nuget.org/v3-flatcontainer/system.collections.specialized/4.3.0/system.collections.specialized.4.3.0.nupkg 3ms
#   GET https://api.nuget.org/v3-flatcontainer/system.threading/4.3.0/system.threading.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.componentmodel/4.3.0/system.componentmodel.4.3.0.nupkg 5ms
#   OK https://api.nuget.org/v3-flatcontainer/system.componentmodel.typeconverter/4.3.0/system.componentmodel.typeconverter.4.3.0.nupkg 6ms
#   OK https://api.nuget.org/v3-flatcontainer/system.threading/4.3.0/system.threading.4.3.0.nupkg 7ms
#   GET https://api.nuget.org/v3-flatcontainer/system.globalization/4.3.0/system.globalization.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.metadata/index.json 853ms
#   OK https://api.nuget.org/v3-flatcontainer/system.globalization/4.3.0/system.globalization.4.3.0.nupkg 20ms
#   OK https://api.nuget.org/v3-flatcontainer/system.xml.xmldocument/index.json 218ms
#   GET https://api.nuget.org/v3-flatcontainer/system.reflection.metadata/1.6.0/system.reflection.metadata.1.6.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.xml.xmldocument/4.3.0/system.xml.xmldocument.4.3.0.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/system.xml.xmldocument/4.3.0/system.xml.xmldocument.4.3.0.nupkg 9ms
#   GET https://api.nuget.org/v3-flatcontainer/system.collections.nongeneric/index.json
#   OK https://api.nuget.org/v3-flatcontainer/system.diagnostics.tracesource/index.json 355ms
#   GET https://api.nuget.org/v3-flatcontainer/system.diagnostics.tracesource/4.3.0/system.diagnostics.tracesource.4.3.0.nupkg
#   GET https://api.nuget.org/v3-flatcontainer/system.globalization.extensions/index.json
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.metadata/1.6.0/system.reflection.metadata.1.6.0.nupkg 43ms
#   OK https://api.nuget.org/v3-flatcontainer/system.diagnostics.tracesource/4.3.0/system.diagnostics.tracesource.4.3.0.nupkg 7ms
#   OK https://api.nuget.org/v3-flatcontainer/system.reflection.primitives/4.3.0/system.reflection.primitives.4.3.0.nupkg 169ms
#   GET https://api.nuget.org/v3-flatcontainer/system.componentmodel.primitives/index.json
#   OK https://api.nuget.org/v3-flatcontainer/netstandard.library/1.6.1/netstandard.library.1.6.1.nupkg 189ms
#   OK https://api.nuget.org/v3-flatcontainer/fsharp.core/8.0.300/fsharp.core.8.0.300.nupkg 220ms
# ...
# Installed runtime.opensuse.42.1-x64.runtime.native.System.Security.Cryptography.OpenSsl 4.3.0 from https://api.nuget.org/v3/index.json with content hash KeLz4HClKf+nFS7p/6Fi/CqyLXh81FpiGzcmuS8DGi9lUqSnZ6Es23/gv2O+1XVGfrbNmviF7CckBpavkBoIFQ==.
# Installed System.Collections.Immutable 8.0.0 from https://api.nuget.org/v3/index.json with content hash AurL6Y5BA1WotzlEvVaIDpqzpIPvYnnldxru8oXJU2yFxFUy3+pNXjXd1ymO+RA0rq0+590Q8gaz2l3Sr7fmqg==.
# Installed Microsoft.Bcl.AsyncInterfaces 8.0.0 from https://api.nuget.org/v3/index.json with content hash 3WA9q9yVqJp222P3x1wYIGDAkpjAku0TMUaaQV22g6L67AI0LdOIrVS7Ht2vJfLHGSPVuqN94vIr15qn+HEkHw==.
# Installed System.Runtime.Loader 4.3.0 from https://api.nuget.org/v3/index.json with content hash DHMaRn8D8YCK2GG2pw+UzNxn/OHVfaWx7OTLBD/hPegHZZgcZh3H6seWegrC4BYwsfuGrywIuT+MQs+rPqRLTQ==.
# Installed runtime.opensuse.13.2-x64.runtime.native.System.Security.Cryptography.OpenSsl 4.3.0 from https://api.nuget.org/v3/index.json with content hash b3pthNgxxFcD+Pc0WSEoC0+md3MyhRS6aCEeenvNE3Fdw1HyJ18ZhRFVJJzIeR/O/jpxPboB805Ho0T3Ul7w8A==.
# Installed runtime.native.System.IO.Compression 4.3.0 from https://api.nuget.org/v3/index.json with content hash INBPonS5QPEgn7naufQFXJEp3zX6L4bwHgJ/ZH78aBTpeNfQMtf7C6VrAFhlq2xxWBveIOWyFzQjJ8XzHMhdOQ==.
# Installed System.Buffers 4.3.0 from https://api.nuget.org/v3/index.json with content hash ratu44uTIHgeBeI0dE8DWvmXVBSo4u7ozRZZHOMmK/JPpYyo0dAfgSiHlpiObMQ5lEtEyIXA40sKRYg5J6A8uQ==.
# Installed System.Threading.Tasks 4.3.0 from https://api.nuget.org/v3/index.json with content hash LbSxKEdOUhVe8BezB/9uOGGppt+nZf6e1VFyw6v3DN6lqitm0OSn2uXMOdtP0M3W4iMcqcivm2J6UgqiwwnXiA==.
# Installed runtime.native.System.Net.Http 4.3.0 from https://api.nuget.org/v3/index.json with content hash ZVuZJqnnegJhd2k/PtAbbIcZ3aZeITq3sj06oKfMBSfphW3HDmk/t4ObvbOk/JA/swGR0LNqMksAh/f7gpTROg==.
# Installed runtime.native.System.Security.Cryptography.OpenSsl 4.3.0 from https://api.nuget.org/v3/index.json with content hash NS1U+700m4KFRHR5o4vo9DSlTmlCKu/u7dtE5sUHVIPB+xpXxYQvgBgA6wEIeCz6Yfn0Z52/72WYsToCEPJnrw==.
# Installed System.Reflection.Emit.Lightweight 4.3.0 from https://api.nuget.org/v3/index.json with content hash oadVHGSMsTmZsAF864QYN1t1QzZjIcuKU3l2S9cZOwDdDueNTrqq1yRj7koFfIGEnKpt6NjpL3rOzRhs4ryOgA==.
# Installed System.Memory 4.5.5 from https://api.nuget.org/v3/index.json with content hash XIWiDvKPXaTveaB7HVganDlOCRoj03l+jrwNvcge/t8vhGYKvqV+dMv6G4SAX2NoNmN0wZfVPTAlFwZcZvVOUw==.
# Installed runtime.native.System.Security.Cryptography.Apple 4.3.0 from https://api.nuget.org/v3/index.json with content hash DloMk88juo0OuOWr56QG7MNchmafTLYWvABy36izkrLI5VledI0rq28KGs1i9wbpeT9NPQrx/wTf8U2vazqQ3Q==.
# Installed System.Diagnostics.DiagnosticSource 8.0.0 from https://api.nuget.org/v3/index.json with content hash c9xLpVz6PL9lp/djOWtk5KPDZq3cSYpmXoJQY524EOtuFl5z9ZtsotpsyrDW40U1DRnQSYvcPKEUV0X//u6gkQ==.
# Installed System.Diagnostics.DiagnosticSource 4.3.0 from https://api.nuget.org/v3/index.json with content hash tD6kosZnTAGdrEa0tZSuFyunMbt/5KYDnHdndJYGqZoNy00XVXyACd5d6KnE1YgYv3ne2CjtAfNXo/fwEhnKUA==.
# Installed System.Security.Cryptography.OpenSsl 4.3.0 from https://api.nuget.org/v3/index.json with content hash h4CEgOgv5PKVF/HwaHzJRiVboL2THYCou97zpmhjghx5frc7fIvlkY1jL+lnIQyChrJDMNEXS6r7byGif8Cy4w==.
# Installed System.Security.Cryptography.Csp 4.3.0 from https://api.nuget.org/v3/index.json with content hash X4s/FCkEUnRGnwR3aSfVIkldBmtURMhmexALNTwpjklzxWU7yjMk7GHLKOZTNkgnWnE0q7+BCf9N2LVRWxewaA==.
# Installed runtime.fedora.24-x64.runtime.native.System.Security.Cryptography.OpenSsl 4.3.0 from https://api.nuget.org/v3/index.json with content hash c3YNH1GQJbfIPJeCnr4avseugSqPrxwIqzthYyZDN6EuOyNOzq+y2KSUfRcXauya1sF4foESTgwM5e1A8arAKw==.
# Installed Microsoft.Bcl.HashCode 1.1.1 from https://api.nuget.org/v3/index.json with content hash MalY0Y/uM/LjXtHfX/26l2VtN4LDNZ2OE3aumNOHDLsT4fNYy2hiHXI4CXCqKpNUNm7iJ2brrc4J89UdaL56FA==.
# Installed System.CommandLine 2.0.0-beta4.22272.1 from https://api.nuget.org/v3/index.json with content hash 1uqED/q2H0kKoLJ4+hI2iPSBSEdTuhfCYADeJrAqERmiGQ2NNacYKRNEQ+gFbU4glgVyK8rxI+ZOe1onEtr/Pg==.
# Installed System.Security.Cryptography.Cng 4.3.0 from https://api.nuget.org/v3/index.json with content hash 03idZOqFlsKRL4W+LuCpJ6dBYDUWReug6lZjBa3uJWnk5sPCUXckocevTaUA8iT/MFSrY/2HXkOt753xQ/cf8g==.
# Installed System.Runtime.CompilerServices.Unsafe 6.0.0 from https://api.nuget.org/v3/index.json with content hash /iUeP3tq1S0XdNNoMz5C9twLSrM/TH+qElHkXWaPvuNOt+99G75NrV0OS2EqHx5wMN7popYjpc8oTjC1y16DLg==.
# Installed runtime.debian.8-x64.runtime.native.System.Security.Cryptography.OpenSsl 4.3.0 from https://api.nuget.org/v3/index.json with content hash HdSSp5MnJSsg08KMfZThpuLPJpPwE5hBXvHwoKWosyHHfe8Mh5WKT0ylEOf6yNzX6Ngjxe4Whkafh5q7Ymac4Q==.
# Installed System.Text.Encodings.Web 4.5.0 from https://api.nuget.org/v3/index.json with content hash Xg4G4Indi4dqP1iuAiMSwpiWS54ZghzR644OtsRCm/m/lBMG8dUBhLVN7hLm8NNrNTR+iGbshCPTwrvxZPlm4g==.
# Installed runtime.fedora.23-x64.runtime.native.System.Security.Cryptography.OpenSsl 4.3.0 from https://api.nuget.org/v3/index.json with content hash +yH1a49wJMy8Zt4yx5RhJrxO/DBDByAiCzNwiETI+1S4mPdCu0OY4djdciC7Vssk0l22wQaDLrXxXkp+3+7bVA==.
# Installed System.Text.Encoding 4.0.11 from https://api.nuget.org/v3/index.json with content hash U3gGeMlDZXxCEiY4DwVLSacg+DFWCvoiX+JThA/rvw37Sqrku7sEFeVBBBMBnfB6FeZHsyDx85HlKL19x0HtZA==.
# Installed Microsoft.CSharp 4.7.0 from https://api.nuget.org/v3/index.json with content hash pTj+D3uJWyN3My70i2Hqo+OXixq3Os2D1nJ2x92FFo6sk8fYS1m1WLNTs0Dc1uPaViH0YvEEwvzddQ7y4rhXmA==.
# Installed System.Xml.ReaderWriter 4.3.0 from https://api.nuget.org/v3/index.json with content hash GrprA+Z0RUXaR4N7/eW71j1rgMnEnEVlgii49GZyAjTH7uliMnrOU3HNFBr6fEDBCJCIdlVNq9hHbaDR621XBA==.
# Installed System.Text.Encodings.Web 8.0.0 from https://api.nuget.org/v3/index.json with content hash yev/k9GHAEGx2Rg3/tU6MQh4HGBXJs70y7j1LaM1i/ER9po+6nnQ6RRqTJn1E7Xu0fbIFK80Nh5EoODxrbxwBQ==.
# Installed System.Runtime 4.1.0 from https://api.nuget.org/v3/index.json with content hash v6c/4Yaa9uWsq+JMhnOFewrYkgdNHNG2eMKuNqRn8P733rNXeRCGvV5FkkjBXn2dbVkPXOsO0xjsEeM1q2zC0g==.
# Installed System.Reflection.Metadata 8.0.0 from https://api.nuget.org/v3/index.json with content hash ptvgrFh7PvWI8bcVqG5rsA/weWM09EnthFHR5SCnS6IN+P4mj6rE1lBDC4U8HL9/57htKAqy4KQ3bBj84cfYyQ==.
# Installed System.Runtime.InteropServices 4.3.0 from https://api.nuget.org/v3/index.json with content hash uv1ynXqiMK8mp1GM3jDqPCFN66eJ5w5XNomaK2XD+TuCroNTLFGeZ+WCmBMcBDyTFKou3P6cR6J/QsaqDp7fGQ==.
# Installed System.Text.Json 8.0.0 from https://api.nuget.org/v3/index.json with content hash OdrZO2WjkiEG6ajEFRABTRCi/wuXQPxeV6g8xvUJqdxMvvuCCEk86zPla8UiIQJz3durtUEbNyY/3lIhS0yZvQ==.
# Installed Microsoft.CodeAnalysis.VisualBasic.Workspaces 4.8.0 from https://api.nuget.org/v3/index.json with content hash 4fNpQX8LRV0ZCfB6+rr9s61zdhNpN6Bgow/kmvsO2Gm5KtzbOUPijbUZex26wJwRHyW+ZYoatTRd449A7+D3Wg==.
# Installed Microsoft.CodeAnalysis.VisualBasic 4.8.0 from https://api.nuget.org/v3/index.json with content hash kfHPh/etcWypMDYfHxgfitgJMhi986OFCICb76RPcA1Toordf6bBYEJytWr2L5CNdkXFWuw5qTkrlsktBav4VA==.
# Installed System.Reactive 6.0.0 from https://api.nuget.org/v3/index.json with content hash 31kfaW4ZupZzPsI5PVe77VhnvFF55qgma7KZr/E0iFTs6fmdhhG8j0mgEx620iLTey1EynOkEfnyTjtNEpJzGw==.
# Installed Microsoft.CodeAnalysis.CSharp.Workspaces 4.8.0 from https://api.nuget.org/v3/index.json with content hash 3amm4tq4Lo8/BGvg9p3BJh3S9nKq2wqCXfS7138i69TUpo/bD+XvD0hNurpEBtcNZhi1FyutiomKJqVF39ugYA==.
# Installed Microsoft.CodeAnalysis.CSharp 4.8.0 from https://api.nuget.org/v3/index.json with content hash +3+qfdb/aaGD8PZRCrsdobbzGs1m9u119SkkJt8e/mk3xLJz/udLtS2T6nY27OTXxBBw10HzAbC8Z9w08VyP/g==.
# Installed System.Runtime 4.3.0 from https://api.nuget.org/v3/index.json with content hash JufQi0vPQ0xGnAczR13AUFglDyVYt4Kqnz1AZaiKZ5+GICq0/1MH/mO/eAJHt/mHW1zjKBJd7kV26SrxddAhiw==.
# Generating MSBuild file /content/Tests/obj/QuantConnect.Tests.csproj.nuget.g.props.
# Generating MSBuild file /content/Tests/obj/QuantConnect.Tests.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Tests/obj/project.assets.json
# Restored /content/Tests/QuantConnect.Tests.csproj (in 17.9 sec).
# Restoring packages for /content/Research/QuantConnect.Research.csproj...
#   GET https://api.nuget.org/v3-flatcontainer/newtonsoft.json/13.0.1/newtonsoft.json.13.0.1.nupkg
#   OK https://api.nuget.org/v3-flatcontainer/newtonsoft.json/13.0.1/newtonsoft.json.13.0.1.nupkg 4ms
# Installed Newtonsoft.Json 13.0.1 from https://api.nuget.org/v3/index.json with content hash ppPFpBcvxdsfUonNcvITKqLl3bqxWbDCZIzDWHzjpdAHRFfZe0Dw9HmA0+za13IdyrgJwpkDTDA9fHaxOrt20A==.
# Generating MSBuild file /content/Research/obj/QuantConnect.Research.csproj.nuget.g.props.
# Generating MSBuild file /content/Research/obj/QuantConnect.Research.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Research/obj/project.assets.json
# Restored /content/Research/QuantConnect.Research.csproj (in 192 ms).
# Restoring packages for /content/Report/QuantConnect.Report.csproj...
# Generating MSBuild file /content/Report/obj/QuantConnect.Report.csproj.nuget.g.props.
# Generating MSBuild file /content/Report/obj/QuantConnect.Report.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Report/obj/project.assets.json
# Restored /content/Report/QuantConnect.Report.csproj (in 12 ms).
# Restoring packages for /content/Queues/QuantConnect.Queues.csproj...
# Generating MSBuild file /content/Queues/obj/QuantConnect.Queues.csproj.nuget.g.props.
# Generating MSBuild file /content/Queues/obj/QuantConnect.Queues.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Queues/obj/project.assets.json
# Restored /content/Queues/QuantConnect.Queues.csproj (in 7 ms).
# Restoring packages for /content/Optimizer/QuantConnect.Optimizer.csproj...
# Generating MSBuild file /content/Optimizer/obj/QuantConnect.Optimizer.csproj.nuget.g.props.
# Generating MSBuild file /content/Optimizer/obj/QuantConnect.Optimizer.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Optimizer/obj/project.assets.json
# Restored /content/Optimizer/QuantConnect.Optimizer.csproj (in 4 ms).
# Restoring packages for /content/Optimizer.Launcher/QuantConnect.Optimizer.Launcher.csproj...
# Generating MSBuild file /content/Optimizer.Launcher/obj/QuantConnect.Optimizer.Launcher.csproj.nuget.g.props.
# Generating MSBuild file /content/Optimizer.Launcher/obj/QuantConnect.Optimizer.Launcher.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Optimizer.Launcher/obj/project.assets.json
# Restored /content/Optimizer.Launcher/QuantConnect.Optimizer.Launcher.csproj (in 5 ms).
# Restoring packages for /content/Messaging/QuantConnect.Messaging.csproj...
# Generating MSBuild file /content/Messaging/obj/QuantConnect.Messaging.csproj.nuget.g.props.
# Generating MSBuild file /content/Messaging/obj/QuantConnect.Messaging.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Messaging/obj/project.assets.json
# Restored /content/Messaging/QuantConnect.Messaging.csproj (in 5 ms).
# Restoring packages for /content/Logging/QuantConnect.Logging.csproj...
# Generating MSBuild file /content/Logging/obj/QuantConnect.Logging.csproj.nuget.g.props.
# Generating MSBuild file /content/Logging/obj/QuantConnect.Logging.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Logging/obj/project.assets.json
# Restored /content/Logging/QuantConnect.Logging.csproj (in 1 ms).
# Restoring packages for /content/Launcher/QuantConnect.Lean.Launcher.csproj...
# Generating MSBuild file /content/Launcher/obj/QuantConnect.Lean.Launcher.csproj.nuget.g.props.
# Generating MSBuild file /content/Launcher/obj/QuantConnect.Lean.Launcher.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Launcher/obj/project.assets.json
# Restored /content/Launcher/QuantConnect.Lean.Launcher.csproj (in 27 ms).
# Restoring packages for /content/Indicators/QuantConnect.Indicators.csproj...
# Generating MSBuild file /content/Indicators/obj/QuantConnect.Indicators.csproj.nuget.g.props.
# Generating MSBuild file /content/Indicators/obj/QuantConnect.Indicators.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Indicators/obj/project.assets.json
# Restored /content/Indicators/QuantConnect.Indicators.csproj (in 5 ms).
# Restoring packages for /content/Engine/QuantConnect.Lean.Engine.csproj...
# Generating MSBuild file /content/Engine/obj/QuantConnect.Lean.Engine.csproj.nuget.g.props.
# Generating MSBuild file /content/Engine/obj/QuantConnect.Lean.Engine.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Engine/obj/project.assets.json
# Restored /content/Engine/QuantConnect.Lean.Engine.csproj (in 7 ms).
# Restoring packages for /content/Algorithm.Python/QuantConnect.Algorithm.Python.csproj...
# Generating MSBuild file /content/Algorithm.Python/obj/QuantConnect.Algorithm.Python.csproj.nuget.g.props.
# Generating MSBuild file /content/Algorithm.Python/obj/QuantConnect.Algorithm.Python.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Algorithm.Python/obj/project.assets.json
# Restored /content/Algorithm.Python/QuantConnect.Algorithm.Python.csproj (in 5 ms).
# Restoring packages for /content/Algorithm.Framework/QuantConnect.Algorithm.Framework.csproj...
# Generating MSBuild file /content/Algorithm.Framework/obj/QuantConnect.Algorithm.Framework.csproj.nuget.g.props.
# Generating MSBuild file /content/Algorithm.Framework/obj/QuantConnect.Algorithm.Framework.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Algorithm.Framework/obj/project.assets.json
# Restored /content/Algorithm.Framework/QuantConnect.Algorithm.Framework.csproj (in 6 ms).
# Restoring packages for /content/Algorithm.CSharp/QuantConnect.Algorithm.CSharp.csproj...
# Generating MSBuild file /content/Algorithm.CSharp/obj/QuantConnect.Algorithm.CSharp.csproj.nuget.g.props.
# Generating MSBuild file /content/Algorithm.CSharp/obj/QuantConnect.Algorithm.CSharp.csproj.nuget.g.targets.
# Writing assets file to disk. Path: /content/Algorithm.CSharp/obj/project.assets.json
# Restored /content/Algorithm.CSharp/QuantConnect.Algorithm.CSharp.csproj (in 8 ms).
#
# NuGet Config files used:
#     /root/.config/NuGet/NuGet.Config
#
# Feeds used:
#     https://api.nuget.org/v3/index.json
#
# Installed:
#     36 package(s) to /content/DownloaderDataProvider/QuantConnect.DownloaderDataProvider.Launcher.csproj
#     4 package(s) to /content/Configuration/QuantConnect.Configuration.csproj
#     12 package(s) to /content/Compression/QuantConnect.Compression.csproj
#     27 package(s) to /content/Common/QuantConnect.csproj
#     30 package(s) to /content/Brokerages/QuantConnect.Brokerages.csproj
#     28 package(s) to /content/Api/QuantConnect.Api.csproj
#     27 package(s) to /content/AlgorithmFactory/QuantConnect.AlgorithmFactory.csproj
#     27 package(s) to /content/Algorithm/QuantConnect.Algorithm.csproj
#     36 package(s) to /content/ToolBox/QuantConnect.ToolBox.csproj
#     212 package(s) to /content/Tests/QuantConnect.Tests.csproj
#     89 package(s) to /content/Research/QuantConnect.Research.csproj
#     48 package(s) to /content/Report/QuantConnect.Report.csproj
#     30 package(s) to /content/Queues/QuantConnect.Queues.csproj
#     27 package(s) to /content/Optimizer/QuantConnect.Optimizer.csproj
#     27 package(s) to /content/Optimizer.Launcher/QuantConnect.Optimizer.Launcher.csproj
#     38 package(s) to /content/Messaging/QuantConnect.Messaging.csproj
#     1 package(s) to /content/Logging/QuantConnect.Logging.csproj
#     99 package(s) to /content/Launcher/QuantConnect.Lean.Launcher.csproj
#     27 package(s) to /content/Indicators/QuantConnect.Indicators.csproj
#     36 package(s) to /content/Engine/QuantConnect.Lean.Engine.csproj
#     27 package(s) to /content/Algorithm.Python/QuantConnect.Algorithm.Python.csproj
#     30 package(s) to /content/Algorithm.Framework/QuantConnect.Algorithm.Framework.csproj
#     33 package(s) to /content/Algorithm.CSharp/QuantConnect.Algorithm.CSharp.csproj
# >

# %%
# Update lean config to use python
import jstyleson
import json

with open('Launcher/config.json') as f:
  result_dict = jstyleson.loads(f.read())

result_dict["algorithm-type-name"] = "BasicTemplateAlgorithm"
result_dict["algorithm-language"] = "Python"
result_dict["algorithm-location"] = "../../../BasicAlgorithm.py"

with open('Launcher/config.json', 'w') as f:
    json.dump(result_dict, f)

# %%
# Save the cell to the file set in the config
# %%writefile BasicAlgorithm.py
# Write your algo below

from clr import AddReference
AddReference("System")
AddReference("QuantConnect.Algorithm")
AddReference("QuantConnect.Common")

from System import *
from QuantConnect import *
from QuantConnect.Algorithm import *
import numpy as np

### <summary>
### Basic template algorithm simply initializes the date range and cash. This is a skeleton
### framework you can use for designing an algorithm.
### </summary>
### <meta name="tag" content="using data" />
### <meta name="tag" content="using quantconnect" />
### <meta name="tag" content="trading and orders" />
class BasicTemplateAlgorithm(QCAlgorithm):
    '''Basic template algorithm simply initializes the date range and cash'''

    def Initialize(self):
        '''Initialise the data and resolution required, as well as the cash and start-end dates for your algorithm. All algorithms must initialized.'''

        self.SetStartDate(2013,10, 7)  #Set Start Date
        self.SetEndDate(2013,10,11)    #Set End Date
        self.SetCash(100000)           #Set Strategy Cash
        # Find more symbols here: http://quantconnect.com/data
        self.AddEquity("SPY", Resolution.Second)
        self.Debug("numpy test >>> print numpy.pi: " + str(np.pi))

    def OnData(self, data):
        '''OnData event is the primary entry point for your algorithm. Each new data point will be pumped in here.
        Arguments:
            data: Slice object keyed by symbol containing the stock data
        '''
        if not self.Portfolio.Invested:
            self.SetHoldings("SPY", 1)
# Out:
# Writing BasicAlgorithm.py

# %%
# !wget https://dot.net/v1/dotnet-install.sh -O dotnet-install.sh
# Out:
# --2024-12-17 12:45:45--  https://dot.net/v1/dotnet-install.sh
# Resolving dot.net (dot.net)... 20.76.201.171, 20.112.250.133, 20.236.44.162, ...
# Connecting to dot.net (dot.net)|20.76.201.171|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://dotnet.microsoft.com/download/dotnet/scripts/v1/dotnet-install.sh [following]
# --2024-12-17 12:45:46--  https://dotnet.microsoft.com/download/dotnet/scripts/v1/dotnet-install.sh
# Resolving dotnet.microsoft.com (dotnet.microsoft.com)... 13.107.246.59, 2620:1ec:bdf::59
# Connecting to dotnet.microsoft.com (dotnet.microsoft.com)|13.107.246.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Cookie coming from dotnet.microsoft.com attempted to set domain to dotnetwebsite.azurewebsites.net
# Cookie coming from dotnet.microsoft.com attempted to set domain to dotnetwebsite.azurewebsites.net
# Length: 63987 (62K) [application/x-sh,application/octet-stream]
# Saving to: ‘dotnet-install.sh’
#
# dotnet-install.sh   100%[===================>]  62.49K   379KB/s    in 0.2s
#
# 2024-12-17 12:45:46 (379 KB/s) - ‘dotnet-install.sh’ saved [63987/63987]

# %%
# !chmod +x ./dotnet-install.sh

# %%
# Build & Run Lean
from IPython.display import clear_output

# !msbuild QuantConnect.Lean.sln
#clear_output(wait=True)
#!cd Launcher/bin/Debug && mono ./QuantConnect.Lean.Launcher.exe
# Out:
# =Microsoft (R) Build Engine version 16.10.1 for Mono
# Copyright (C) Microsoft Corporation. All rights reserved.
#
# Building the projects in this solution one at a time. To enable parallel build, please add the "-m" switch.
# Build started 12/17/2024 12:47:25 PM.
# Project "/content/QuantConnect.Lean.sln" on node 1 (default targets).
# ValidateSolutionConfiguration:
#   Building solution configuration "Debug|Any CPU".
# ValidateProjects:
#   The project "QuantConnect.Algorithm.Python" is not selected for building in solution configuration "Debug|Any CPU".
#   It was not possible to find any installed dotnet SDKs
#   Did you mean to run dotnet SDK commands? Please install dotnet SDK from:
#       https://aka.ms/dotnet-download
#   It was not possible to find any installed dotnet SDKs
#   Did you mean to run dotnet SDK commands? Please install dotnet SDK from:
#       https://aka.ms/dotnet-download
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Launcher/QuantConnect.Lean.Launcher.csproj" (2) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Launcher/QuantConnect.Lean.Launcher.csproj]
# Done Building Project "/content/Launcher/QuantConnect.Lean.Launcher.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Algorithm/QuantConnect.Algorithm.csproj" (3) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Algorithm/QuantConnect.Algorithm.csproj]
# Done Building Project "/content/Algorithm/QuantConnect.Algorithm.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Common/QuantConnect.csproj" (4) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Common/QuantConnect.csproj]
# Done Building Project "/content/Common/QuantConnect.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Logging/QuantConnect.Logging.csproj" (5) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Logging/QuantConnect.Logging.csproj]
# Done Building Project "/content/Logging/QuantConnect.Logging.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Indicators/QuantConnect.Indicators.csproj" (6) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Indicators/QuantConnect.Indicators.csproj]
# Done Building Project "/content/Indicators/QuantConnect.Indicators.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Tests/QuantConnect.Tests.csproj" (7) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Tests/QuantConnect.Tests.csproj]
# Done Building Project "/content/Tests/QuantConnect.Tests.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Queues/QuantConnect.Queues.csproj" (8) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Queues/QuantConnect.Queues.csproj]
# Done Building Project "/content/Queues/QuantConnect.Queues.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Messaging/QuantConnect.Messaging.csproj" (9) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Messaging/QuantConnect.Messaging.csproj]
# Done Building Project "/content/Messaging/QuantConnect.Messaging.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/AlgorithmFactory/QuantConnect.AlgorithmFactory.csproj" (10) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/AlgorithmFactory/QuantConnect.AlgorithmFactory.csproj]
# Done Building Project "/content/AlgorithmFactory/QuantConnect.AlgorithmFactory.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Brokerages/QuantConnect.Brokerages.csproj" (11) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Brokerages/QuantConnect.Brokerages.csproj]
# Done Building Project "/content/Brokerages/QuantConnect.Brokerages.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Configuration/QuantConnect.Configuration.csproj" (12) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Configuration/QuantConnect.Configuration.csproj]
# Done Building Project "/content/Configuration/QuantConnect.Configuration.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Compression/QuantConnect.Compression.csproj" (13) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Compression/QuantConnect.Compression.csproj]
# Done Building Project "/content/Compression/QuantConnect.Compression.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Api/QuantConnect.Api.csproj" (14) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Api/QuantConnect.Api.csproj]
# Done Building Project "/content/Api/QuantConnect.Api.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Algorithm.CSharp/QuantConnect.Algorithm.CSharp.csproj" (15) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Algorithm.CSharp/QuantConnect.Algorithm.CSharp.csproj]
# Done Building Project "/content/Algorithm.CSharp/QuantConnect.Algorithm.CSharp.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/ToolBox/QuantConnect.ToolBox.csproj" (16) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/ToolBox/QuantConnect.ToolBox.csproj]
# Done Building Project "/content/ToolBox/QuantConnect.ToolBox.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Research/QuantConnect.Research.csproj" (17) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Research/QuantConnect.Research.csproj]
# Done Building Project "/content/Research/QuantConnect.Research.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Algorithm.Framework/QuantConnect.Algorithm.Framework.csproj" (18) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Algorithm.Framework/QuantConnect.Algorithm.Framework.csproj]
# Done Building Project "/content/Algorithm.Framework/QuantConnect.Algorithm.Framework.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Report/QuantConnect.Report.csproj" (19) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Report/QuantConnect.Report.csproj]
# Done Building Project "/content/Report/QuantConnect.Report.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Optimizer/QuantConnect.Optimizer.csproj" (20) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Optimizer/QuantConnect.Optimizer.csproj]
# Done Building Project "/content/Optimizer/QuantConnect.Optimizer.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/Optimizer.Launcher/QuantConnect.Optimizer.Launcher.csproj" (21) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Optimizer.Launcher/QuantConnect.Optimizer.Launcher.csproj]
# Done Building Project "/content/Optimizer.Launcher/QuantConnect.Optimizer.Launcher.csproj" (default targets) -- FAILED.
# Project "/content/QuantConnect.Lean.sln" (1) is building "/content/DownloaderDataProvider/QuantConnect.DownloaderDataProvider.Launcher.csproj" (22) on node 1 (default targets).
# /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/DownloaderDataProvider/QuantConnect.DownloaderDataProvider.Launcher.csproj]
# Done Building Project "/content/DownloaderDataProvider/QuantConnect.DownloaderDataProvider.Launcher.csproj" (default targets) -- FAILED.
# Done Building Project "/content/QuantConnect.Lean.sln" (default targets) -- FAILED.
#
# Build FAILED.
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Launcher/QuantConnect.Lean.Launcher.csproj" (default target) (2) ->
# (GetReferenceAssemblyPaths target) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Launcher/QuantConnect.Lean.Launcher.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Algorithm/QuantConnect.Algorithm.csproj" (default target) (3) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Algorithm/QuantConnect.Algorithm.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Common/QuantConnect.csproj" (default target) (4) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Common/QuantConnect.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Logging/QuantConnect.Logging.csproj" (default target) (5) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Logging/QuantConnect.Logging.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Indicators/QuantConnect.Indicators.csproj" (default target) (6) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Indicators/QuantConnect.Indicators.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Tests/QuantConnect.Tests.csproj" (default target) (7) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Tests/QuantConnect.Tests.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Queues/QuantConnect.Queues.csproj" (default target) (8) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Queues/QuantConnect.Queues.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Messaging/QuantConnect.Messaging.csproj" (default target) (9) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Messaging/QuantConnect.Messaging.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/AlgorithmFactory/QuantConnect.AlgorithmFactory.csproj" (default target) (10) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/AlgorithmFactory/QuantConnect.AlgorithmFactory.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Brokerages/QuantConnect.Brokerages.csproj" (default target) (11) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Brokerages/QuantConnect.Brokerages.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Configuration/QuantConnect.Configuration.csproj" (default target) (12) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Configuration/QuantConnect.Configuration.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Compression/QuantConnect.Compression.csproj" (default target) (13) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Compression/QuantConnect.Compression.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Api/QuantConnect.Api.csproj" (default target) (14) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Api/QuantConnect.Api.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Algorithm.CSharp/QuantConnect.Algorithm.CSharp.csproj" (default target) (15) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Algorithm.CSharp/QuantConnect.Algorithm.CSharp.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/ToolBox/QuantConnect.ToolBox.csproj" (default target) (16) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/ToolBox/QuantConnect.ToolBox.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Research/QuantConnect.Research.csproj" (default target) (17) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Research/QuantConnect.Research.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Algorithm.Framework/QuantConnect.Algorithm.Framework.csproj" (default target) (18) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Algorithm.Framework/QuantConnect.Algorithm.Framework.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Report/QuantConnect.Report.csproj" (default target) (19) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Report/QuantConnect.Report.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Optimizer/QuantConnect.Optimizer.csproj" (default target) (20) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Optimizer/QuantConnect.Optimizer.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/Optimizer.Launcher/QuantConnect.Optimizer.Launcher.csproj" (default target) (21) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/Optimizer.Launcher/QuantConnect.Optimizer.Launcher.csproj]
#
#
# "/content/QuantConnect.Lean.sln" (default target) (1) ->
# "/content/DownloaderDataProvider/QuantConnect.DownloaderDataProvider.Launcher.csproj" (default target) (22) ->
#   /usr/lib/mono/msbuild/Current/bin/Microsoft.Common.CurrentVersion.targets(1232,5): error MSB3971: The reference assemblies for ".NETFramework,Version=v6.0" were not found. You might be using an older .NET SDK to target .NET 5.0 or higher. Update Visual Studio and/or your .NET SDK. [/content/DownloaderDataProvider/QuantConnect.DownloaderDataProvider.Launcher.csproj]
#
#     0 Warning(s)
#     21 Error(s)
#
# Time Elapsed 00:00:02.38
# >
